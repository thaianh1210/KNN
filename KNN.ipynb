# %% [markdown]
# <a href="https://colab.research.google.com/github/thaianh1210/KNN/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Load the iris dataset
iris_X, iris_y = datasets.load_iris(return_X_y=True)

# Split the dataset into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(iris_X, iris_y, test_size=0.2, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
accuracies = []
for i in range(1, 30):
  knn_classifier = KNeighborsClassifier(n_neighbors= i, p = 2)
  knn_classifier.fit(X_train, y_train)

  y_pred = knn_classifier.predict(X_test)
  accuracy = accuracy_score(y_pred, y_test)
  accuracies.append(accuracy)

# %%
import matplotlib.pyplot as plt
k_values = range(1, 30)
def plot_iris(X, y):
    # Create scatter plot for each class
    plt.figure(figsize=(8, 6))
    plt.plot(k_values, accuracies)
    plt.title('Iris Dataset')
    plt.xlabel('K values')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# Now you can call this function with your training data
plot_iris(X_train, y_train)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
